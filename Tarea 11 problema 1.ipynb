# %% [markdown]
# #Tarea 11, problema 1

# %% [markdown]
# Emilio Carranza Ávila
# Gustavo Ibáñez Sosa
# Gabriela Lozano Orozco
# Karen Manguart Páez

# %%
# !pip install -q pyomo
# !apt-get install -y -qq glpk-utils
# !apt-get install -y -qq coinor-cbc
# Out:
#      |████████████████████████████████| 9.6 MB 1.8 MB/s
#      |████████████████████████████████| 49 kB 2.3 MB/s
# Selecting previously unselected package libsuitesparseconfig5:amd64.
# (Reading database ... 156210 files and directories currently installed.)
# Preparing to unpack .../libsuitesparseconfig5_1%3a5.1.2-2_amd64.deb ...
# Unpacking libsuitesparseconfig5:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libamd2:amd64.
# Preparing to unpack .../libamd2_1%3a5.1.2-2_amd64.deb ...
# Unpacking libamd2:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libcolamd2:amd64.
# Preparing to unpack .../libcolamd2_1%3a5.1.2-2_amd64.deb ...
# Unpacking libcolamd2:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libglpk40:amd64.
# Preparing to unpack .../libglpk40_4.65-1_amd64.deb ...
# Unpacking libglpk40:amd64 (4.65-1) ...
# Selecting previously unselected package glpk-utils.
# Preparing to unpack .../glpk-utils_4.65-1_amd64.deb ...
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Diet Problem

# %%
# !pyomo solve --solver=glpk /content/drive/MyDrive/'Colab Notebooks'/'Tarea 11 optimización'/diet.py /content/drive/MyDrive/'Colab Notebooks'/'Tarea 11 optimización'/diet.dat
# Out:
# [    0.00] Setting up Pyomo environment
# [    0.00] Applying Pyomo preprocessing actions
# [    0.00] Pyomo Finished
# ERROR: Unexpected exception while running model:
#         File /content/drive/MyDrive/Colab Notebooks/Tarea 11
#         optimización/diet.py does not exist!

# %% [markdown]
# # New Section

# %%
# !cat results.yml
# Out:
# cat: results.yml: No such file or directory

# %% [markdown]
# # Max Flow

# %%
# !pyomo solve --solver=glpk /content/drive/MyDrive/'Colab Notebooks'/'Tarea 11 optimización'/maxflow.py /content/drive/MyDrive/'Colab Notebooks'/'Tarea 11 optimización'/maxflow.dat
# Out:
# [    0.00] Setting up Pyomo environment
# [    0.00] Applying Pyomo preprocessing actions
# [    0.00] Pyomo Finished
# ERROR: Unexpected exception while running model:
#         File /content/drive/MyDrive/Colab Notebooks/Tarea 11
#         optimización/maxflow.py does not exist!

# %%
# !cat results.yml
# Out:
# cat: results.yml: No such file or directory

# %% [markdown]
# # P-Median problem

# %%
# !pyomo solve --solver=glpk /content/drive/MyDrive/'Colab Notebooks'/'Tarea 11 optimización'/p-median.py /content/drive/MyDrive/'Colab Notebooks'/'Tarea 11 optimización'/p-median.dat
# Out:
# [    0.00] Setting up Pyomo environment
# [    0.00] Applying Pyomo preprocessing actions
# [    0.00] Pyomo Finished
# ERROR: Unexpected exception while running model:
#         File /content/drive/MyDrive/Colab Notebooks/Tarea 11
#         optimización/p-median.py does not exist!

# %%
# !cat results.yml
# Out:
# cat: results.yml: No such file or directory

# %% [markdown]
# # Transport Problem

# %%
# !pyomo solve --solver=glpk /content/drive/MyDrive/'Colab Notebooks'/'Tarea 11 optimización'/transport.py
# Out:
# [    0.00] Setting up Pyomo environment
# [    0.00] Applying Pyomo preprocessing actions
# [    0.00] Pyomo Finished
# ERROR: Unexpected exception while running model:
#         File /content/drive/MyDrive/Colab Notebooks/Tarea 11
#         optimización/transport.py does not exist!

# %%
# !cat results.yml
# Out:
# cat: results.yml: No such file or directory

# %% [markdown]
# # Min-cost-flow*

# %%
# !cat /content/drive/MyDrive/'Colab Notebooks'/'Tarea 11 optimización'/min_cost_flow.py
# Out:
# cat: '/content/drive/MyDrive/Colab Notebooks/Tarea 11 optimización/min_cost_flow.py': No such file or directory

# %%
# !python /content/drive/MyDrive/'Colab Notebooks/Tarea 11 optimización'/min_cost_flow.py
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Colab Notebooks/Tarea 11 optimización/min_cost_flow.py", line 86, in <module>
#     sp = MinCostFlow('/content/drive/MyDrive/Colab Notebooks/Tarea 11 optimización/nodes.csv', '/content/drive/MyDrive/Colab Notebooks/Tarea 11 optimización/arcs.csv')
#   File "/content/drive/MyDrive/Colab Notebooks/Tarea 11 optimización/min_cost_flow.py", line 25, in __init__
#     self.arc_data = pandas.read_csv('/content/drive/MyDrive/Colab Notebooks/Tarea 11 optimización/arcs.csv')
#   File "/usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
# ...

# %% [markdown]
# # Network interdiction

# %% [markdown]
# ## Shortest path interdiction

# %%
# !cat /content/drive/MyDrive/'Colab Notebooks'/'Tarea 11 optimización'/sp_interdict.py
# Out:
# cat: '/content/drive/MyDrive/Colab Notebooks/Tarea 11 optimización/sp_interdict.py': No such file or directory

# %%
# !python /content/drive/MyDrive/'Colab Notebooks'/'Tarea 11 optimización'/sp_interdict.py
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Colab Notebooks/Tarea 11 optimización/sp_interdict.py", line 209, in <module>
#     m = SPInterdiction('sample_nodes_data_sp.csv', 'sample_arcs_data_sp.csv')
#   File "/content/drive/MyDrive/Colab Notebooks/Tarea 11 optimización/sp_interdict.py", line 21, in __init__
#     self.node_data = pandas.read_csv(nodefile)
#   File "/usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "/usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
# ...

# %% [markdown]
# ## Max flow interdiction

# %%
# !cat /content/drive/MyDrive/'Colab Notebooks'/'Tarea 11 optimización'/max_flow_interdict.py
# Out:
# import pandas
# import pyomo
# import pyomo.opt
# import pyomo.environ as pe
# import logging
#
# class MaxFlowInterdiction:
#     """A class to compute max-flow interdictions."""
#
#     def __init__(self, nodefile, arcfile, attacks=0):
#         """
#         All the files are CSVs with columns described below.  Attacks is the number of attacks.
#         - nodefile:
#             Node
#         Every node must appear as a line in the nodefile. There are two special nodes called 'Start' and 'End' that define the source and sink of the max-flow problem.
#         - arcfile:
#             StartNode,EndNode,Capacity,Attackable
#         Every arc must appear in the arcfile.  The data also describes the arc's capacity and whether we can attack this arc.
#         """
#         # Read in the node_data
#         self.node_data = pandas.read_csv(nodefile)
#         self.node_data.set_index(['Node'], inplace=True)
#         self.node_data.sort_index(inplace=True)
# ...

# %%
# !python /content/drive/MyDrive/'Colab Notebooks'/'Tarea 11 optimización'/max_flow_interdict.py
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Colab Notebooks/Tarea 11 optimización/max_flow_interdict.py", line 198, in <module>
#     m = MaxFlowInterdiction('sample_nodes_data_mf.csv', 'sample_arcs_data_mf.csv')
#   File "/content/drive/MyDrive/Colab Notebooks/Tarea 11 optimización/max_flow_interdict.py", line 21, in __init__
#     self.node_data = pandas.read_csv(nodefile)
#   File "/usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "/usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
# ...

# %% [markdown]
# ## Min cost flow interdiction

# %%
# !cat /content/drive/MyDrive/'Colab Notebooks'/'Tarea 11 optimización'/min_cost_flow_interdict.py
# Out:
# {
#  "metadata": {
#   "name": "",
#   "signature": "sha256:3203a62c794b056e9202075c3d2f3cde57af44eeb452a1c3f9b1d52b52e69f8a"
#  },
#  "nbformat": 3,
#  "nbformat_minor": 0,
#  "worksheets": [
#   {
#    "cells": [
#     {
#      "cell_type": "code",
#      "collapsed": false,
#      "input": [
#       "%load min_cost_flow_interdict.py"
#      ],
#      "language": "python",
#      "metadata": {},
#      "outputs": [],
#      "prompt_number": 1
#     },
#     {
#      "cell_type": "code",
#      "collapsed": false,
#      "input": [
#       "import networkx\n",
#       "import pandas\n",
#       "import pyomo\n",
#       "import pyomo.opt\n",
#       "import pyomo.environ as pe\n",
#       "import scipy\n",
#       "import itertools\n",
#       "import logging\n",
#       "\n",
#       "class MinCostFlowInterdiction:\n",
#       "    \"\"\"A class to compute min-cost-flow interdictions.\"\"\"\n",
#       "\n",
#       "    def __init__(self, nodefile, arcfile, attacks=0):\n",
# ...

# %% [markdown]
# ## Multi commodity flow interdiction

# %%
# !cat /content/drive/MyDrive/'Colab Notebooks'/'Tarea 11 optimización'/multi_commodity_flow_interdict.py
# Out:
# import pandas
# import pyomo
# import pyomo.opt
# import pyomo.environ as pe
# import logging
#
# class MultiCommodityInterdiction:
#     """A class to compute multicommodity flow interdictions."""
#
#     def __init__(self, nodefile, node_commodity_file, arcfile, arc_commodity_file, attacks=0):
#         """
#         All the files are CSVs with columns described below.  Attacks is the number of attacks.
#         - nodefile:
#             Node
#         Every node must appear as a line in the nodefile.  You can have additional columns as well.
#         - node_commodity_file:
#             Node,Commodity,SupplyDemand
#         Every commodity node imbalance that is not zero must appear in the node_commodity_file
#         - arcfile:
#             StartNode,EndNode,Capacity,Attackable
#         Every arc must appear in the arcfile.  Also the arcs total capacity and whether we can attack this arc.
#         - arc_commodity_file:
# ...

# %%
# !python /content/drive/MyDrive/'Colab Notebooks'/'Tarea 11 optimización'/multi_commodity_flow_interdict.py
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Colab Notebooks/Tarea 11 optimización/multi_commodity_flow_interdict.py", line 256, in <module>
#     m = MultiCommodityInterdiction('sample_nodes_data_multi.csv', 'sample_nodes_commodity_data.csv', 'sample_arcs_data_multi.csv', 'sample_arcs_commodity_data.csv')
#   File "/content/drive/MyDrive/Colab Notebooks/Tarea 11 optimización/multi_commodity_flow_interdict.py", line 27, in __init__
#     self.node_data = pandas.read_csv(nodefile)
#   File "/usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
# ...

# %% [markdown]
# # Row Generation and MST

# %%
# !cat /content/drive/MyDrive/'Colab Notebooks'/'Tarea 11 optimización'/mst.py
# Out:
# import pyomo
# import pyomo.opt
# import pyomo.environ as pe
# import pandas
# import networkx
#
# class MSTRowGeneration:
#     """A class to find Minimum Spanning Tree using a row-generation algorithm."""
#
#     def __init__(self, nfile):
#         """The input is a CSV file describing the undirected network's edges."""
#         self.df = pandas.read_csv(nfile)
#
#         self.createRelaxedModel()
#
#     def createRelaxedModel(self):
#         """Create the relaxed model, without any subtour elimination constraints."""
#         df = self.df
#         node_set = set( list( df.startNode ) + list(df.destNode) )
#
#         # Create the model and sets
#         m = pe.ConcreteModel()
#
#         df.set_index(['startNode','destNode'], inplace=True)
#         edge_set = df.index.unique()
#
#         m.edge_set = pe.Set(initialize=edge_set, dimen=2)
#         m.node_set = pe.Set(initialize=node_set)
#
#         # Define variables
#         m.Y = pe.Var(m.edge_set, domain=pe.Binary)
# ...

# %%
# !python /content/drive/MyDrive/'Colab Notebooks'/'Tarea 11 optimización'/mst.py
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Colab Notebooks/Tarea 11 optimización/mst.py", line 82, in <module>
#     mst = MSTRowGeneration('mst.csv')
#   File "/content/drive/MyDrive/Colab Notebooks/Tarea 11 optimización/mst.py", line 12, in __init__
#     self.df = pandas.read_csv(nfile)
#   File "/usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "/usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
# ...
